# %% [markdown]
# # Plotting and Customizing Quantum Circuits using MatRenderer
#
# Author: Rushiraj Gadhvi (gadhvirushiraj@gmail.com)
#
# This notebook serves as a comprehensive guide to plotting quantum circuits using QuTiP-QIP's MatRenderer, a Matplotlib-based rendering tool. It explores the various customization options available to users for creating and modifying plots. The content is organized into two main sections:
#
# - **Circuit-Level Customization**
# - **Gate-Level Customization**

# %%
import qutip
import numpy as np
from qutip import Qobj
from qutip_qip.operations import rx
from qutip_qip.circuit import QubitCircuit

# %%
qc = QubitCircuit(2, num_cbits=1)
qc.add_gate("CNOT", controls=0, targets=1)
qc.add_gate("SNOT", targets=1)
qc.add_gate("ISWAP", targets=[0, 1])
qc.add_measurement("M0", targets=1, classical_store=0)
# Out:
# /tmp/ipykernel_9504/3496603573.py:2: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("CNOT", controls=0, targets=1)
# /tmp/ipykernel_9504/3496603573.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("SNOT", targets=1)
# /tmp/ipykernel_9504/3496603573.py:4: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("ISWAP", targets=[0, 1])

# %%
qc.draw()

# %% [markdown]
# ---
#
# ### Circuit Level Customization Options
#
# ---
#
# ##### Changing FontSize

# %%
qc.draw(fontsize=13)

# %% [markdown]
# ##### Background Color

# %%
qc.draw(bgcolor="gray")

# %% [markdown]
# ##### Gate Bulge Control

# %%
qc.draw(bulge=False)

# %% [markdown]
# ##### Custom Wire Labels

# %%
qc.draw(wire_label=["some_name", "some_long_name", "long_long_name"])

# %% [markdown]
# ##### Control extra wire extension at end of circuit

# %%
qc.draw(end_wire_ext=0)

# %%
qc.draw(end_wire_ext=5)

# %% [markdown]
# ##### Condense Circuit

# %%
qc.draw(gate_margin=0.1)

# %% [markdown]
# ##### Adding Title

# %%
qc.draw(title="QuTiP")

# %% [markdown]
# ##### Changing Theme

# %%
qc.draw(theme="light")

# %%
qc.draw(theme="dark", title="QuTiP")

# %%
qc.draw(theme="modern")

# %% [markdown]
# ##### Aligning Layer

# %%
qc = QubitCircuit(3)
qc.add_gate("H", targets=[1])
qc.add_gate("RZ", targets=[2], arg_value=0.5, style={"showarg": True})
qc.add_gate("RZ", targets=[2], arg_value=0.5, style={"showarg": True})
qc.add_gate("CNOT", controls=[0], targets=[1], style={"showarg": True})
qc.add_gate("CNOT", controls=[0], targets=[1], style={"showarg": True})
qc.add_gate("SWAP", targets=[0, 2])
# Out:
# /tmp/ipykernel_9504/4176097664.py:2: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[1])
# /tmp/ipykernel_9504/4176097664.py:3: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("RZ", targets=[2], arg_value=0.5, style={"showarg": True})
# /tmp/ipykernel_9504/4176097664.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("RZ", targets=[2], arg_value=0.5, style={"showarg": True})
# /tmp/ipykernel_9504/4176097664.py:4: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("RZ", targets=[2], arg_value=0.5, style={"showarg": True})
# /tmp/ipykernel_9504/4176097664.py:4: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("RZ", targets=[2], arg_value=0.5, style={"showarg": True})
# /tmp/ipykernel_9504/4176097664.py:5: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("CNOT", controls=[0], targets=[1], style={"showarg": True})
# /tmp/ipykernel_9504/4176097664.py:6: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("CNOT", controls=[0], targets=[1], style={"showarg": True})
# /tmp/ipykernel_9504/4176097664.py:7: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("SWAP", targets=[0, 2])

# %%
# not-aligned gates
qc.draw(theme="modern")

# %%
# aligned gates
qc.draw(align_layer=True, theme="modern")

# %% [markdown]
# ---
#
# ### Gate Level Customization Options
#
# ---

# %%
qc = QubitCircuit(7)
qc.add_gate("H", targets=[0], style={"fontcolor": "red"})
qc.add_gate("H", targets=[1], style={"fontstyle": "italic"})
qc.add_gate("H", targets=[2], style={"fontweight": "bold"})
qc.add_gate("H", targets=[3], style={"color": "green"})
qc.add_gate("H", targets=[4], style={"fontsize": 12})
qc.add_gate("H", targets=[5], arg_label="hadamard gate")
qc.add_gate("H", targets=[6], style={"fontfamily": "cursive"})
# Out:
# /tmp/ipykernel_9504/25304991.py:2: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[0], style={"fontcolor": "red"})
# /tmp/ipykernel_9504/25304991.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[1], style={"fontstyle": "italic"})
# /tmp/ipykernel_9504/25304991.py:4: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[2], style={"fontweight": "bold"})
# /tmp/ipykernel_9504/25304991.py:5: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[3], style={"color": "green"})
# /tmp/ipykernel_9504/25304991.py:6: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[4], style={"fontsize": 12})
# /tmp/ipykernel_9504/25304991.py:7: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("H", targets=[5], arg_label="hadamard gate")
# /tmp/ipykernel_9504/25304991.py:7: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[5], arg_label="hadamard gate")
# /tmp/ipykernel_9504/25304991.py:8: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[6], style={"fontfamily": "cursive"})

# %%
qc.draw()
# Out:
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive

# %% [markdown]
# ##### Rendering Argument Value

# %%
qc = QubitCircuit(3)
qc.add_gate("RX", targets=[0], arg_value=np.pi / 12, style={"showarg": True})
qc.add_gate(
    "RY", targets=[1], arg_value=2 * np.pi / 3, style={"showarg": True}
)
qc.add_gate("RY", targets=[2], arg_value=0.3, style={"showarg": True})
qc.draw()
# Out:
# /tmp/ipykernel_9504/4114587668.py:2: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("RX", targets=[0], arg_value=np.pi / 12, style={"showarg": True})
# /tmp/ipykernel_9504/4114587668.py:2: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("RX", targets=[0], arg_value=np.pi / 12, style={"showarg": True})
# /tmp/ipykernel_9504/4114587668.py:3: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate(
# /tmp/ipykernel_9504/4114587668.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate(
# /tmp/ipykernel_9504/4114587668.py:6: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("RY", targets=[2], arg_value=0.3, style={"showarg": True})
# /tmp/ipykernel_9504/4114587668.py:6: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("RY", targets=[2], arg_value=0.3, style={"showarg": True})

# %% [markdown]
# #### With User Custom Gates

# %%
def user_gate1(arg_value):
    # controlled rotation X
    mat = np.zeros((4, 4), dtype=complex)
    mat[0, 0] = mat[1, 1] = 1.0
    mat[2:4, 2:4] = rx(arg_value).full()
    return Qobj(mat, dims=[[2, 2], [2, 2]])


def user_gate2():
    # S gate
    mat = np.array([[1.0, 0], [0.0, 1.0j]])
    return Qobj(mat, dims=[[2], [2]])

# %%
qc = QubitCircuit(3)
qc.user_gates = {"CTRLRX": user_gate1, "S": user_gate2}

# qubit 1 controls qubit 0
qc.add_gate("CTRLRX", targets=[1, 0], arg_value=np.pi / 2)
# qubit 2 is target of S gate
qc.add_gate("S", targets=[2])
# Out:
# /tmp/ipykernel_9504/1405759453.py:2: DeprecationWarning: Using circuit.user_gates with string gate names is deprecated. Please define custom gates as Gate classes instead.
#   qc.user_gates = {"CTRLRX": user_gate1, "S": user_gate2}
# /tmp/ipykernel_9504/1179489056.py:5: DeprecationWarning: rxRTNOT has been deprecated and will be removed in future version.         Use RX(angle).get_qobj() instead.
#   mat[2:4, 2:4] = rx(arg_value).full()
# /tmp/ipykernel_9504/1405759453.py:5: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("CTRLRX", targets=[1, 0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1405759453.py:7: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("S", targets=[2])

# %%
qc.draw()

# %% [markdown]
# ---
#
# ### Some more circuit examples
#
# ---

# %%
trotter_simulation_noisey = QubitCircuit(4)

trotter_simulation_noisey.add_gate("RZ", targets=[0], arg_value=np.pi / 2)
trotter_simulation_noisey.add_gate("RZ", targets=[1], arg_value=np.pi / 2)

trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=1)
trotter_simulation_noisey.add_gate("RX", targets=[0], arg_value=np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=1)

trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
trotter_simulation_noisey.add_gate("RX", targets=[0], arg_value=np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)

trotter_simulation_noisey.add_gate("RZ", targets=[2], arg_value=-np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
trotter_simulation_noisey.add_gate("RY", targets=[0], arg_value=np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
trotter_simulation_noisey.add_gate("RZ", targets=[2], arg_value=np.pi / 2)

trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
trotter_simulation_noisey.add_gate("RX", targets=[1], arg_value=np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)

trotter_simulation_noisey.add_gate("RZ", targets=[3], arg_value=-np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
trotter_simulation_noisey.add_gate("RY", targets=[1], arg_value=np.pi / 2)
trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
trotter_simulation_noisey.add_gate("RZ", targets=[3], arg_value=np.pi / 2)

trotter_simulation_noisey.draw(theme="dark", title="Trotter Simulation")
# Out:
# /tmp/ipykernel_9504/1106497282.py:3: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RZ", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RZ", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:4: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RZ", targets=[1], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:4: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RZ", targets=[1], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:6: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=1)
# /tmp/ipykernel_9504/1106497282.py:7: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RX", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:7: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RX", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:8: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=1)
# /tmp/ipykernel_9504/1106497282.py:10: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
# /tmp/ipykernel_9504/1106497282.py:11: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RX", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:11: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RX", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:12: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
# /tmp/ipykernel_9504/1106497282.py:14: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RZ", targets=[2], arg_value=-np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:14: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RZ", targets=[2], arg_value=-np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:15: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
# /tmp/ipykernel_9504/1106497282.py:16: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RY", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:16: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RY", targets=[0], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:17: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=0, targets=2)
# /tmp/ipykernel_9504/1106497282.py:18: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RZ", targets=[2], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:18: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RZ", targets=[2], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:20: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
# /tmp/ipykernel_9504/1106497282.py:21: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RX", targets=[1], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:21: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RX", targets=[1], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:22: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
# /tmp/ipykernel_9504/1106497282.py:24: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RZ", targets=[3], arg_value=-np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:24: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RZ", targets=[3], arg_value=-np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:25: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
# /tmp/ipykernel_9504/1106497282.py:26: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RY", targets=[1], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:26: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RY", targets=[1], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:27: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("CNOT", controls=1, targets=3)
# /tmp/ipykernel_9504/1106497282.py:28: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   trotter_simulation_noisey.add_gate("RZ", targets=[3], arg_value=np.pi / 2)
# /tmp/ipykernel_9504/1106497282.py:28: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   trotter_simulation_noisey.add_gate("RZ", targets=[3], arg_value=np.pi / 2)

# %% [markdown]
# ---

# %%
qutip.about()
# Out:
# QuTiP: Quantum Toolbox in Python
# ================================
# Copyright (c) QuTiP team 2011 and later.
# Current admin team: Alexander Pitchford, Nathan Shammah, Shahnawaz Ahmed, Neill Lambert, Eric Giguère, Boxi Li, Simon Cross, Asier Galicia, Paul Menczel, and Patrick Hopf.
# Board members: Daniel Burgarth, Robert Johansson, Anton F. Kockum, Franco Nori and Will Zeng.
# Original developers: R. J. Johansson & P. D. Nation.
# Previous lead developers: Chris Granade & A. Grimsmo.
# Currently developed through wide collaboration. See https://github.com/qutip for details.
#
# QuTiP Version:      5.3.0.dev0+369e192
# Numpy Version:      2.4.3
# Scipy Version:      1.17.1
# Cython Version:     3.2.4
# Matplotlib Version: 3.10.8
# Python Version:     3.12.0
# Number of CPUs:     4
# BLAS Info:          blas
# INTEL MKL Ext:      None
# Platform Info:      Linux (x86_64)
# Installation path:  /home/runner/miniconda3/envs/test-environment-v5/lib/python3.12/site-packages/qutip
#
# Installed QuTiP family packages
# -------------------------------
# qutip-jax: 0.1.1.dev8
# qutip-qip: 0.5.0.dev390+git.bacf97a1
# qutip-qtrl: 0.2.0.dev0+acb71a0
# qutip-qoc: 0.3.0.dev0+ba7b283
#
# ================================================================================
# Please cite QuTiP in your publication.
# ================================================================================
# For your convenience a bibtex reference can be easily generated using `qutip.cite()`
