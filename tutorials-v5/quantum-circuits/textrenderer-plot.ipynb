# %% [markdown]
# # Plotting and Customizing Quantum Circuits using TextRenderer
# Author: Rushiraj Gadhvi (gadhvirushiraj@gmail.com)
#
# This notebook serves as a comprehensive guide to plotting quantum circuits using QuTiP-QIP's TextRenderer. It explores the various customization options available to users for creating and modifying plots.
#
# - **Circuit-Level Customization**
# - **Gate-Level Customization**

# %%
import qutip
import numpy as np
from qutip import Qobj
from qutip_qip.operations import rx
from qutip_qip.circuit import QubitCircuit

# %%
qc = QubitCircuit(2, num_cbits=1)
qc.add_gate("CNOT", controls=0, targets=1)
qc.add_gate("SNOT", targets=1)
qc.add_gate("ISWAP", targets=[0, 1])
qc.add_measurement("M0", targets=1, classical_store=0)
# Out:
# /tmp/ipykernel_9462/3496603573.py:2: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("CNOT", controls=0, targets=1)
# /tmp/ipykernel_9462/3496603573.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("SNOT", targets=1)
# /tmp/ipykernel_9462/3496603573.py:4: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("ISWAP", targets=[0, 1])

# %%
qc.draw("text")
# Out:
#         ┌────┐  ┌───┐  ┌───────┐  ┌───┐
#  q1 :───┤ CX ├──┤ H ├──┤       ├──┤ M ├───
#         └──┬─┘  └───┘  │       │  └─╥─┘
#            │           │       │    ║
#  q0 :──────█───────────┤ ISWAP ├────║─────
#                        └───────┘    ║
#                                     ║
#  c0 :═══════════════════════════════╩═════

# %% [markdown]
# ---
# ### Circuit Level Customization Options
# ---

# %% [markdown]
# ##### Custom Wire Labels

# %%
qc.draw("text", wire_label=["some_name", "some_long_name", "long_long_name"])
# Out:
#                     ┌────┐  ┌───┐  ┌───────┐  ┌───┐
#  long_long_name :───┤ CX ├──┤ H ├──┤       ├──┤ M ├───
#                     └──┬─┘  └───┘  │       │  └─╥─┘
#                        │           │       │    ║
#  some_long_name :──────█───────────┤ ISWAP ├────║─────
#                                    └───────┘    ║
#                                                 ║
#  some_name      :═══════════════════════════════╩═════

# %% [markdown]
# ##### Control extra wire extension at end of circuit

# %%
qc.draw("text", end_wire_ext=0)
# Out:
#         ┌────┐  ┌───┐  ┌───────┐  ┌───┐
#  q1 :───┤ CX ├──┤ H ├──┤       ├──┤ M ├─
#         └──┬─┘  └───┘  │       │  └─╥─┘
#            │           │       │    ║
#  q0 :──────█───────────┤ ISWAP ├────║───
#                        └───────┘    ║
#                                     ║
#  c0 :═══════════════════════════════╩═══

# %%
qc.draw("text", end_wire_ext=5)
# Out:
#         ┌────┐  ┌───┐  ┌───────┐  ┌───┐
#  q1 :───┤ CX ├──┤ H ├──┤       ├──┤ M ├──────
#         └──┬─┘  └───┘  │       │  └─╥─┘
#            │           │       │    ║
#  q0 :──────█───────────┤ ISWAP ├────║────────
#                        └───────┘    ║
#                                     ║
#  c0 :═══════════════════════════════╩════════

# %% [markdown]
# ##### Adjust Gate Padding

# %%
qc.draw("text", gate_pad=3)
# Out:
#         ┌────────┐  ┌───────┐  ┌───────────┐  ┌───────┐
#  q1 :───┤   CX   ├──┤   H   ├──┤           ├──┤   M   ├───
#         └────┬───┘  └───────┘  │           │  └───╥───┘
#              │                 │           │      ║
#  q0 :────────█─────────────────┤   ISWAP   ├──────║───────
#                                └───────────┘      ║
#                                                   ║
#  c0 :═════════════════════════════════════════════╩═══════

# %% [markdown]
# ---
# ### Gate Level Customization Options
# ---

# %%
qc = QubitCircuit(2)
qc.add_gate("H", targets=[0])
qc.add_gate("H", targets=[1], arg_label="hadamard gate")
# Out:
# /tmp/ipykernel_9462/652804881.py:2: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[0])
# /tmp/ipykernel_9462/652804881.py:3: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("H", targets=[1], arg_label="hadamard gate")
# /tmp/ipykernel_9462/652804881.py:3: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("H", targets=[1], arg_label="hadamard gate")

# %%
qc.draw("text")
# Out:
#         ┌───┐
#  q1 :───┤ H ├───
#         └───┘
#         ┌───┐
#  q0 :───┤ H ├───
#         └───┘

# %% [markdown]
# #### With User Custom Gates

# %%
def user_gate1(arg_value=np.pi / 2):
    # controlled rotation X
    mat = np.zeros((4, 4), dtype=complex)
    mat[0, 0] = mat[1, 1] = 1.0
    mat[2:4, 2:4] = rx(arg_value).full()
    return Qobj(mat, dims=[[2, 2], [2, 2]])


def user_gate2():
    # S gate
    mat = np.array([[1.0, 0], [0.0, 1.0j]])
    return Qobj(mat, dims=[[2], [2]])

# %%
qc = QubitCircuit(3)
qc.user_gates = {"CTRLRX": user_gate1, "S": user_gate2}

# qubit 1 controls qubit 0
qc.add_gate("CTRLRX", targets=[1, 0], arg_value=np.pi / 2)
# qubit 2 is target of S gate
qc.add_gate("S", targets=[2])
# Out:
# /tmp/ipykernel_9462/1405759453.py:2: DeprecationWarning: Using circuit.user_gates with string gate names is deprecated. Please define custom gates as Gate classes instead.
#   qc.user_gates = {"CTRLRX": user_gate1, "S": user_gate2}
# /tmp/ipykernel_9462/3761281703.py:5: DeprecationWarning: rxRTNOT has been deprecated and will be removed in future version.         Use RX(angle).get_qobj() instead.
#   mat[2:4, 2:4] = rx(arg_value).full()
# /tmp/ipykernel_9462/1405759453.py:5: DeprecationWarning: Define 'arg_value', 'arg_label' in your Gate object e.g. RX(np.pi), 'arg_value', 'arg_label' arguments will be removed from 'add_gate' method in the future version.
# Please refer to the tutorial for the recommended way to define them:
# https://nbviewer.org/urls/qutip.org/qutip-tutorials/tutorials-v5/quantum-circuits/quantum-gates.ipynb
#   qc.add_gate("CTRLRX", targets=[1, 0], arg_value=np.pi / 2)
# /tmp/ipykernel_9462/1405759453.py:7: DeprecationWarning: Passing Gate as a string input has been deprecated and will be removed in future versions.
#   qc.add_gate("S", targets=[2])

# %%
qc.draw("text")
# Out:
#         ┌───┐
#  q2 :───┤ S ├────────
#         └───┘
#         ┌────────┐
#  q1 :───┤        ├───
#         │        │
#         │        │
#  q0 :───┤ CTRLRX ├───
#         └────────┘

# %% [markdown]
# ---

# %%
qutip.about()
# Out:
# QuTiP: Quantum Toolbox in Python
# ================================
# Copyright (c) QuTiP team 2011 and later.
# Current admin team: Alexander Pitchford, Nathan Shammah, Shahnawaz Ahmed, Neill Lambert, Eric Giguère, Boxi Li, Simon Cross, Asier Galicia, Paul Menczel, and Patrick Hopf.
# Board members: Daniel Burgarth, Robert Johansson, Anton F. Kockum, Franco Nori and Will Zeng.
# Original developers: R. J. Johansson & P. D. Nation.
# Previous lead developers: Chris Granade & A. Grimsmo.
# Currently developed through wide collaboration. See https://github.com/qutip for details.
#
# QuTiP Version:      5.3.0.dev0+369e192
# Numpy Version:      2.4.3
# Scipy Version:      1.17.1
# Cython Version:     3.2.4
# Matplotlib Version: 3.10.8
# Python Version:     3.12.0
# Number of CPUs:     4
# BLAS Info:          blas
# INTEL MKL Ext:      None
# Platform Info:      Linux (x86_64)
# Installation path:  /home/runner/miniconda3/envs/test-environment-v5/lib/python3.12/site-packages/qutip
#
# Installed QuTiP family packages
# -------------------------------
# qutip-jax: 0.1.1.dev8
# qutip-qip: 0.5.0.dev390+git.bacf97a1
# qutip-qtrl: 0.2.0.dev0+acb71a0
# qutip-qoc: 0.3.0.dev0+ba7b283
#
# ================================================================================
# Please cite QuTiP in your publication.
# ================================================================================
# For your convenience a bibtex reference can be easily generated using `qutip.cite()`
